# %% [markdown]
# # Extract Projects
# Cleans up the data from projects.json
#
# This notebook will:
# - Read `data/raw/projects.json`
# - Flatten projects into tabular form
# - Extract nested arrays into separate tables:
#   - Projects
#   - Project Followers (with `project_id`)
# - Parse timestamps and add `scraped_at` to each row
# - Save to `data/*.parquet`

# %%
import json
from pathlib import Path
import pandas as pd

OUTPUT = Path('../../data')

projects_path = '../../data/raw/projects.json'
parquet_out = OUTPUT / 'projects.parquet'

with open(projects_path, 'r') as f:
    raw = json.load(f)

# %%
projects = raw.get('projects', [])
scraped_at = raw.get('scraped_at')

parse_dt = lambda s: pd.to_datetime(s, errors='coerce', utc=True) if pd.notna(s) else pd.NaT

proj_cols = [
    'id', 'title', 'description', 'category', 'devlogs_count', 'total_seconds_coded',
    'is_shipped','readme_link','demo_link','repo_link','user_id','slack_id','x','y',
    'created_at','updated_at','banner'
]
proj_records = []
for p in projects:
    rec = {k: p.get(k) for k in proj_cols}
    rec['created_at'] = parse_dt(rec.get('created_at'))
    rec['updated_at'] = parse_dt(rec.get('updated_at'))
    rec['scraped_at'] = parse_dt(scraped_at) if scraped_at else pd.Timestamp.utcnow()
    proj_records.append(rec)

df_projects = pd.DataFrame(proj_records)

follower_records = []
for p in projects:
    for f in p.get('followers', []) or []:
        follower_records.append({
            'project_id': p.get('id'),
            'follower_id': f.get('id'),
            'follower_name': f.get('name'),
            'scraped_at': parse_dt(scraped_at) if scraped_at else pd.Timestamp.utcnow(),
        })

df_followers = pd.DataFrame(follower_records)
df_projects
# Out:
#          id                         title  \
# 0         3                  dreamland.js
# 1         4                      Reactive
# 2         6  Summer of making Share votes
# 3         7                         Nomen
# 4         8                       aram.sh
# ...     ...                           ...
# 8790  11762              Personal Website
# 8791  11763                     tinyspark
# 8792  11764                        Panell
# 8793  11765     AI bill management system
# 8794  11766           Rock Paper Scissors
#
#                                             description        category  \
# 0     Utilitarian web framework smaller than preact....  Something else
# 1                                  First site in react!         Web App
# 2               did it with high seas.. we doing it now  Something else
# 3     A web viewer and parser for every name listed ...         Web App
# 4     Remake of my website! Features interactive pho...         Web App
# ...                                                 ...             ...
# 8790  A personal website designed to share my work, ...            None
# 8791  (TinyWow-inspired)[tinywow.com] project gradua...            None
# 8792  A home-hub that shows you useful info on the fly!            None
# 8793  A ai bill management system build for govt. or...            None
# 8794                  Play the rock paper scissors game            None
#
#       devlogs_count  total_seconds_coded  is_shipped  \
# 0                16               106565       False
# 1                 0                    0       False
# 2                 5                17946       False
# 3                 5                11756       False
# 4                 3                21748       False
# ...             ...                  ...         ...
# 8790              2                 5635       False
# 8791              0                    0       False
# 8792              2                 4939       False
# 8793              1                 2951       False
# 8794              0                    0       False
#
#                                             readme_link  \
# 0     https://raw.githubusercontent.com/MercuryWorks...
# 1
# 2     https://raw.githubusercontent.com/NeonGamerBot...
# 3     https://raw.githubusercontent.com/aramshiva/no...
# 4     https://raw.githubusercontent.com/aramshiva/we...
# ...                                                 ...
# 8790  https://raw.githubusercontent.com/Rainier-PS/P...
# 8791  https://raw.githubusercontent.com/emb3rcia/tin...
# 8792
# 8793  https://raw.githubusercontent.com/aryan6673/bi...
# 8794
#
#                                               demo_link  \
# 0     https://mercuryworkshop.github.io/dreamland2-p...
# 1
# 2     https://chromewebstore.google.com/detail/som-v...
# 3                                      https://nomen.sh
# 4                                       https://aram.sh
# ...                                                 ...
# 8790     https://rainier-ps.github.io/Personal-Website/
# 8791
# 8792
# 8793                        https://kvs.deyweaver.live/
# 8794
#
#                                               repo_link  user_id     slack_id  \
# 0     https://github.com/MercuryWorkshop/dreamlandjs...       14  U07UY5CR7U5
# 1                                                             12  U0824G9PTFE
# 2          https://github.com/NeonGamerBot-QK/som-votes        5  U07L45W79E1
# 3                    https://github.com/aramshiva/nomen       39  U0616280E6P
# 4                  https://github.com/aramshiva/website       39  U0616280E6P
# ...                                                 ...      ...          ...
# 8790     https://github.com/Rainier-PS/Personal-Website    12389  U091JD51Z50
# 8791              https://github.com/emb3rcia/tinyspark    15974  U095RD2NX8F
# 8792                                                       18075  U096YQZV3V0
# 8793                  https://github.com/aryan6673/bill     5074  U08MVDFCKJ8
# 8794                                                       16667  U096QEL0W5U
#
#               x          y                       created_at  \
# 0           NaN        NaN 2025-06-16 00:00:06.951000+00:00
# 1           NaN        NaN 2025-06-16 00:02:07.258000+00:00
# 2     34.986536  65.917251 2025-06-16 00:47:20.524000+00:00
# 3     91.518325  81.661442 2025-06-16 00:53:49.627000+00:00
# 4     26.446281  32.489451 2025-06-16 00:56:31.879000+00:00
# ...         ...        ...                              ...
# 8790        NaN        NaN 2025-08-19 14:21:42.287000+00:00
# 8791        NaN        NaN 2025-08-19 14:22:36.978000+00:00
# 8792        NaN        NaN 2025-08-19 14:25:10.457000+00:00
# 8793        NaN        NaN 2025-08-19 14:34:53.866000+00:00
# 8794        NaN        NaN 2025-08-19 14:57:03.575000+00:00
#
#                            updated_at  \
# 0    2025-07-30 20:03:23.829000+00:00
# 1    2025-06-16 00:02:07.258000+00:00
# 2    2025-07-18 20:55:05.945000+00:00
# 3    2025-08-16 13:54:34.590000+00:00
# 4    2025-08-07 05:16:38.665000+00:00
# ...                               ...
# 8790 2025-08-19 14:21:42.287000+00:00
# 8791 2025-08-19 14:22:37.986000+00:00
# 8792 2025-08-19 14:25:10.457000+00:00
# 8793 2025-08-19 14:34:54.941000+00:00
# 8794 2025-08-19 14:57:03.575000+00:00
#
#                                                  banner  \
# 0     https://summer.hackclub.com/rails/active_stora...
# 1                                                  None
# 2     https://summer.hackclub.com/rails/active_stora...
# 3     https://summer.hackclub.com/rails/active_stora...
# 4     https://summer.hackclub.com/rails/active_stora...
# ...                                                 ...
# 8790                                               None
# 8791  https://summer.hackclub.com/rails/active_stora...
# 8792                                               None
# 8793  https://summer.hackclub.com/rails/active_stora...
# 8794                                               None
#
#                            scraped_at
# 0    2025-08-19 15:06:56.124000+00:00
# 1    2025-08-19 15:06:56.124000+00:00
# 2    2025-08-19 15:06:56.124000+00:00
# 3    2025-08-19 15:06:56.124000+00:00
# 4    2025-08-19 15:06:56.124000+00:00
# ...                               ...
# 8790 2025-08-19 15:06:56.124000+00:00
# 8791 2025-08-19 15:06:56.124000+00:00
# 8792 2025-08-19 15:06:56.124000+00:00
# 8793 2025-08-19 15:06:56.124000+00:00
# 8794 2025-08-19 15:06:56.124000+00:00
#
# [8795 rows x 18 columns]

# %%
paths = {
    'projects': OUTPUT / 'projects.parquet',
    'followers': OUTPUT / 'project_followers.parquet',
}

if not df_projects.empty:
    df_projects.to_parquet(paths['projects'], engine="pyarrow", index=False)
if not df_followers.empty:
    df_followers.to_parquet(paths['followers'], engine="pyarrow", index=False)

print('Saved:')
for name, p in paths.items():
    if p.exists():
        print(f' - {name}: {p}')

print('\nRow counts:')
print({
    'projects': len(df_projects),
    'followers': len(df_followers),
})
# Out:
# Saved:
#  - projects: ../../data/projects.parquet
#  - followers: ../../data/project_followers.parquet
#
# Row counts:
# {'projects': 8795, 'followers': 2910}

# %%
df_followers
# Out:
#       project_id  follower_id          follower_name  \
# 0              3           31          3rr0rc0d3z3r0
# 1              3          126               dave9123
# 2              3            5                   Neon
# 3              3            3                   nora
# 4              3         7077  I'm literally a duck.
# ...          ...          ...                    ...
# 2905       11652         8068                  Jagan
# 2906       11673        21481                  Lemon
# 2907       11698        20537           Aaron Rashid
# 2908       11748         4943                   Josh
# 2909       11748         8233                    twa
#
#                            scraped_at
# 0    2025-08-19 15:06:56.124000+00:00
# 1    2025-08-19 15:06:56.124000+00:00
# 2    2025-08-19 15:06:56.124000+00:00
# 3    2025-08-19 15:06:56.124000+00:00
# 4    2025-08-19 15:06:56.124000+00:00
# ...                               ...
# 2905 2025-08-19 15:06:56.124000+00:00
# 2906 2025-08-19 15:06:56.124000+00:00
# 2907 2025-08-19 15:06:56.124000+00:00
# 2908 2025-08-19 15:06:56.124000+00:00
# 2909 2025-08-19 15:06:56.124000+00:00
#
# [2910 rows x 4 columns]
