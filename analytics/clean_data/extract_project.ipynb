# %% [markdown]
# # Extract Projects
# Cleans up the data from projects.json
#
# This notebook will:
# - Read `data/raw/projects.json`
# - Flatten projects into tabular form
# - Extract nested arrays into separate tables:
#   - Projects
#   - Project Followers (with `project_id`)
# - Parse timestamps and add `scraped_at` to each row
# - Save to `data/*.parquet`

# %%
import json
from pathlib import Path
import pandas as pd

OUTPUT = Path('../../data')

projects_path = '../../data/raw/projects.json'
parquet_out = OUTPUT / 'projects.parquet'

with open(projects_path, 'r') as f:
    raw = json.load(f)

# %%
projects = raw.get('projects', [])
scraped_at = raw.get('scraped_at')

parse_dt = lambda s: pd.to_datetime(s, errors='coerce', utc=True) if pd.notna(s) else pd.NaT

proj_cols = [
    'id', 'title', 'description', 'category', 'devlogs_count', 'total_seconds_coded',
    'is_shipped','readme_link','demo_link','repo_link','user_id','slack_id','x','y',
    'created_at','updated_at','banner'
]
proj_records = []
for p in projects:
    rec = {k: p.get(k) for k in proj_cols}
    rec['created_at'] = parse_dt(rec.get('created_at'))
    rec['updated_at'] = parse_dt(rec.get('updated_at'))
    rec['scraped_at'] = parse_dt(scraped_at) if scraped_at else pd.Timestamp.utcnow()
    proj_records.append(rec)

df_projects = pd.DataFrame(proj_records)

follower_records = []
for p in projects:
    for f in p.get('followers', []) or []:
        follower_records.append({
            'project_id': p.get('id'),
            'follower_id': f.get('id'),
            'follower_name': f.get('name'),
            'scraped_at': parse_dt(scraped_at) if scraped_at else pd.Timestamp.utcnow(),
        })

df_followers = pd.DataFrame(follower_records)
df_projects
# Out:
#          id                                              title  \
# 0         3                                       dreamland.js
# 1         4                                           Reactive
# 2         5                                           MusicMap
# 3         6                       Summer of making Share votes
# 4         7                                              Nomen
# ...     ...                                                ...
# 8469  11054  Cats are Liquid (alits) Speedrun Timer (frontend)
# 8470  11055                                          SimpleRPG
# 8471  11056                                      Overclock API
# 8472  11057                                          portfoilo
# 8473  11058                                      Regreso Utils
#
#                                             description        category  \
# 0     Utilitarian web framework smaller than preact....  Something else
# 1                                  First site in react!         Web App
# 2     How we feel for Music, currently has the playl...      Mobile App
# 3               did it with high seas.. we doing it now  Something else
# 4     A web viewer and parser for every name listed ...         Web App
# ...                                                 ...             ...
# 8469  The frontend for my CaL speedrun timer.\r\n\r\...            None
# 8470                                        My rpg game            None
# 8471  An API mod  for Balatro that intends to keep i...            None
# 8472  guam's portfolio (also known as mine)'s portfo...            None
# 8473  A utility package for doing cool bookmark-app-...            None
#
#       devlogs_count  total_seconds_coded  is_shipped  \
# 0                16               106565       False
# 1                 0                    0       False
# 2                 9               359516       False
# 3                 5                17946       False
# 4                 5                14619       False
# ...             ...                  ...         ...
# 8469              0                    0       False
# 8470              0                    0       False
# 8471              0                    0       False
# 8472              1                  381       False
# 8473              0                    0       False
#
#                                             readme_link  \
# 0     https://raw.githubusercontent.com/MercuryWorks...
# 1
# 2     https://raw.githubusercontent.com/N1k0s1/Music...
# 3     https://raw.githubusercontent.com/NeonGamerBot...
# 4     https://raw.githubusercontent.com/aramshiva/no...
# ...                                                 ...
# 8469  https://raw.githubusercontent.com/fily-gif/ali...
# 8470
# 8471  https://raw.githubusercontent.com/basil-square...
# 8472  https://raw.githubusercontent.com/guamothy/por...
# 8473  https://raw.githubusercontent.com/regresado/ut...
#
#                                               demo_link  \
# 0     https://mercuryworkshop.github.io/dreamland2-p...
# 1
# 2     https://github.com/N1k0s1/MusicMap/releases/ta...
# 3     https://chromewebstore.google.com/detail/som-v...
# 4                                      https://nomen.sh
# ...                                                 ...
# 8469
# 8470
# 8471
# 8472              https://guamothy.github.io/portfoilo/
# 8473       https://www.npmjs.com/package/@regreso/utils
#
#                                               repo_link  user_id     slack_id  \
# 0     https://github.com/MercuryWorkshop/dreamlandjs...       14  U07UY5CR7U5
# 1                                                             12  U0824G9PTFE
# 2                    https://github.com/N1k0s1/MusicMap       22  U07960MD940
# 3          https://github.com/NeonGamerBot-QK/som-votes        5  U07L45W79E1
# 4                    https://github.com/aramshiva/nomen       39  U0616280E6P
# ...                                                 ...      ...          ...
# 8469                https://github.com/fily-gif/alitsfe     3478  U082U8N45B5
# 8470                                                        3490  U0878K0L352
# 8471     https://github.com/basil-squared/Overclock-API     2979  U07MJ75J4PK
# 8472              https://github.com/guamothy/portfoilo    20612  U099K0T2JM6
# 8473                 https://github.com/regresado/utils     6428  U07VA44DNBA
#
#               x          y                       created_at  \
# 0           NaN        NaN 2025-06-16 00:00:06.951000+00:00
# 1           NaN        NaN 2025-06-16 00:02:07.258000+00:00
# 2           NaN        NaN 2025-06-16 00:22:22.251000+00:00
# 3     34.986536  65.917251 2025-06-16 00:47:20.524000+00:00
# 4     91.518325  81.661442 2025-06-16 00:53:49.627000+00:00
# ...         ...        ...                              ...
# 8469        NaN        NaN 2025-08-12 22:37:06.977000+00:00
# 8470        NaN        NaN 2025-08-12 22:42:50.510000+00:00
# 8471        NaN        NaN 2025-08-12 23:46:11.867000+00:00
# 8472        NaN        NaN 2025-08-13 00:09:01.884000+00:00
# 8473        NaN        NaN 2025-08-13 01:17:21.140000+00:00
#
#                            updated_at  \
# 0    2025-07-30 20:03:23.829000+00:00
# 1    2025-06-16 00:02:07.258000+00:00
# 2    2025-08-13 01:05:50.288000+00:00
# 3    2025-07-18 20:55:05.945000+00:00
# 4    2025-08-12 06:36:40.944000+00:00
# ...                               ...
# 8469 2025-08-12 22:37:06.977000+00:00
# 8470 2025-08-12 22:42:50.510000+00:00
# 8471 2025-08-12 23:46:11.867000+00:00
# 8472 2025-08-13 00:14:01.968000+00:00
# 8473 2025-08-13 01:17:21.140000+00:00
#
#                                                  banner  \
# 0     https://summer.hackclub.com/rails/active_stora...
# 1                                                  None
# 2     https://summer.hackclub.com/rails/active_stora...
# 3     https://summer.hackclub.com/rails/active_stora...
# 4     https://summer.hackclub.com/rails/active_stora...
# ...                                                 ...
# 8469                                               None
# 8470                                               None
# 8471                                               None
# 8472  https://summer.hackclub.com/rails/active_stora...
# 8473                                               None
#
#                            scraped_at
# 0    2025-08-13 01:42:24.702000+00:00
# 1    2025-08-13 01:42:24.702000+00:00
# 2    2025-08-13 01:42:24.702000+00:00
# 3    2025-08-13 01:42:24.702000+00:00
# 4    2025-08-13 01:42:24.702000+00:00
# ...                               ...
# 8469 2025-08-13 01:42:24.702000+00:00
# 8470 2025-08-13 01:42:24.702000+00:00
# 8471 2025-08-13 01:42:24.702000+00:00
# 8472 2025-08-13 01:42:24.702000+00:00
# 8473 2025-08-13 01:42:24.702000+00:00
#
# [8474 rows x 18 columns]

# %%
paths = {
    'projects': OUTPUT / 'projects.parquet',
    'followers': OUTPUT / 'project_followers.parquet',
}

if not df_projects.empty:
    df_projects.to_parquet(paths['projects'], engine="pyarrow", index=False)
if not df_followers.empty:
    df_followers.to_parquet(paths['followers'], engine="pyarrow", index=False)

print('Saved:')
for name, p in paths.items():
    if p.exists():
        print(f' - {name}: {p}')

print('\nRow counts:')
print({
    'projects': len(df_projects),
    'followers': len(df_followers),
})
# Out:
# Saved:
#  - projects: ../../data/projects.parquet
#  - followers: ../../data/project_followers.parquet
#
# Row counts:
# {'projects': 8474, 'followers': 2821}

# %%
df_followers
# Out:
#       project_id  follower_id                    follower_name  \
# 0              3           31                    3rr0rc0d3z3r0
# 1              3          126                         dave9123
# 2              3            5                             Neon
# 3              3            3                             nora
# 4              3         7077  Ghost of Gay of Ghost of Zombie
# ...          ...          ...                              ...
# 2816       10967        21427                  Kristian Baraka
# 2817       10972        14057                             Alex
# 2818       10998         2191                            Sabio
# 2819       11011        14057                             Alex
# 2820       11013         1834                          Aakriti
#
#                            scraped_at
# 0    2025-08-13 01:42:24.702000+00:00
# 1    2025-08-13 01:42:24.702000+00:00
# 2    2025-08-13 01:42:24.702000+00:00
# 3    2025-08-13 01:42:24.702000+00:00
# 4    2025-08-13 01:42:24.702000+00:00
# ...                               ...
# 2816 2025-08-13 01:42:24.702000+00:00
# 2817 2025-08-13 01:42:24.702000+00:00
# 2818 2025-08-13 01:42:24.702000+00:00
# 2819 2025-08-13 01:42:24.702000+00:00
# 2820 2025-08-13 01:42:24.702000+00:00
#
# [2821 rows x 4 columns]
